# %%
import pandas as pd
df_dict=pd.DataFrame({'name':['Asha','Ravi','Meera'],
                       'age':[24,30,26],
                       'dept':['HR','IT','Finance']})
print("DataFrame from Dictionary:\n",df_dict)
df_csv= pd.read_csv('students.csv')
print("DataFrame from CSV:\n",df_csv)
df_xlsx= pd.read_excel('employees.xlsx')
print("DataFrame from Excel:\n",df_xlsx)
df_json= pd.read_json('data.json')
print("DataFrame from JSON:\n",df_json)
# Out:
# DataFrame from Dictionary:
#      name  age     dept
# 0   Asha   24       HR
# 1   Ravi   30       IT
# 2  Meera   26  Finance
# DataFrame from CSV:
#        Name  Age Grade  Subject
# 0    Alice   20     A     Math
# 1      Bob   21     B  Science
# 2  Charlie   22     A  English
# DataFrame from Excel:
#      Name  Age Department  Salary
# 0   Asha   24         HR   35000
# 1   Ravi   30         IT   50000
# 2  Meera   26    Finance   40000
# DataFrame from JSON:
#     Name  Age Grade
# 0  Arun   22     A
# 1  Binu   21     B
