# %%
import pandas as pd
data=[
    ["Ammu", 23, "Python"],
    ["manu", 25, "Django"],
    ["Anu", 22, "React"]
]
df_list=pd.DataFrame(data,columns=["Name", "Age", "Course"],index=["S1", "S2", "S3"])
print("DataFrame from list:\n",df_list)
data= [
    ("Pen", 10),
    ("Book", 50),
    ("Bag", 700)
]
df_tuple=pd.DataFrame(data,columns=["Item", "Price"])
print("DataFrame from tuple:\n",df_tuple)
df_csv=pd.read_csv('marks.csv',sep="|",header=None,names=["ID","Name","Mark"])
print("DataFrame from CSV:\n",df_csv)
df_xlsx=pd.read_excel('employees.xlsx',usecols=['Name','Salary'])
print("Read only slected columns:\n",df_xlsx)
df_json=pd.read_json("data.json")
Agrade=df_json[df_json["Grade"]=="A"]
print("Student with Grade A:\n",Agrade)
# Out:
# DataFrame from list:
#      Name  Age  Course
# S1  Ammu   23  Python
# S2  manu   25  Django
# S3   Anu   22   React
# DataFrame from tuple:
#     Item  Price
# 0   Pen     10
# 1  Book     50
# 2   Bag    700
# DataFrame from CSV:
#     ID    Name  Mark
# 0   1    Arun    85
# 1   2    Binu    78
# 2   3  Chitra    92
# Read only slected columns:
#      Name  Salary
# 0   Asha   35000
# 1   Ravi   50000
# 2  Meera   40000
# Student with Grade A:
#     Name  Age Grade
# 0  Arun   22     A
